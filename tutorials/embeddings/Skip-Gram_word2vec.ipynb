# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
print(text[:100])
# Out:
#  anarchism originated as a term of abuse first used against early working class radicals including t

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[:100])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580, 0, 194, 10, 190, 58, 4, 5, 10712, 214, 6, 1324, 104, 454, 19, 58, 2731, 362, 6, 3672, 0, 708, 1, 371, 26, 40, 36, 53, 539, 97, 11, 5, 1423, 2757, 18, 567, 686, 7088, 0, 247, 5233, 10, 1052, 27, 0, 320, 248, 44611, 2877, 792, 186, 5233, 11, 5, 200, 602, 10, 0, 1134, 19, 2621, 25, 8983, 2, 279, 31, 4147, 141, 59, 25, 6437]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_counts = len(int_words)
frequency_word = {word: freq/total_counts for word, freq in word_counts.items()}
prob_drop = {word: 1-np.sqrt(threshold/frequency_word[word]) for word in frequency_word}
# The final subsampled word list
# train_words = [word for word in int_words if prob_drop[word] < random.random()]
train_words = [word for word in int_words if random.random() < (1 - prob_drop[word])]

# %%
print(train_words[:100])
# Out:
# [5233, 3133, 741, 10571, 27349, 102, 15067, 58112, 150, 854, 3580, 58, 10712, 58, 2731, 371, 539, 7088, 5233, 44611, 2877, 792, 5233, 2621, 8983, 2, 4147, 6437, 4186, 1137, 4860, 6753, 7573, 93, 11064, 7088, 5948, 4861, 20299, 53721, 25636, 527, 7573, 371, 1206, 7573, 1576, 15200, 7088, 4860, 5690, 755, 4105, 1131, 8117, 686, 7088, 2033, 1423, 8174, 371, 948, 4778, 139, 1821, 8399, 8040, 24172, 1693, 4778, 1556, 8118, 1465, 24172, 12743, 6130, 19, 21148, 16455, 7239, 1193, 10207, 2514, 15068, 12297, 7088, 11064, 3055, 12060, 4778, 6598, 14622, 450, 24172, 295, 20027, 20300, 53722, 24172, 20300]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if idx - R > 0 else 0
    end = idx + R
    target = set(words[start: idx] + words[idx+1: end+1])
    
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.random_uniform((n_vocab, n_embedding), minval=-1, maxval=1)
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# 子目录或文件 checkpoints 已经存在。

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6471 0.3516 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6253 0.3508 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4843 0.3534 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6294 0.3523 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5345 0.3563 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6098 0.3406 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5812 0.3446 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6179 0.3452 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5293 0.3400 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5147 0.3383 sec/batch
# Nearest to not: fibonacci, kaunda, agrippina, hooks, leibniz, transferring, shenanigans, pazzi,
# Nearest to three: appendant, phoenicia, entrenchment, ethel, vigilant, insurrection, scoreless, personaggi,
# Nearest to no: float, incapacitated, segr, islamism, hawai, stadtbahn, burnham, capensis,
# Nearest to however: liddy, rugby, nullity, opec, stosunku, leyte, xxxvii, hydrazine,
# Nearest to during: wilf, obsoletes, kimchi, translations, heathrow, anxiety, cq, mornington,
# Nearest to between: czech, archangels, jettison, deists, subhas, moderates, jesus, thermidor,
# Nearest to i: macho, complementing, paxton, eventual, tres, lasker, branden, correctly,
# Nearest to system: buttressed, sequels, ridge, equatoguinean, dioxin, fulda, screename, hodder,
# Nearest to mean: overseer, ensconced, affect, tors, underpants, mellon, factors, coupon,
# Nearest to paris: mcdonalds, complexion, lepton, xix, downturns, wire, shane, vassar,
# Nearest to assembly: kuznetsova, kessler, gillis, stabilize, siegel, thorton, skid, leland,
# Nearest to derived: alleges, jeffreys, leaving, emulsions, avalon, smp, grok, resonating,
# Nearest to running: zap, philippians, personality, gniezno, lesund, rence, bukit, seahawks,
# Nearest to ice: murdered, government, possessed, desires, ramanuja, spade, wildest, photographers,
# Nearest to shown: ascertaining, laurentian, gassed, philharmonic, grasping, converge, watchtower, ona,
# Nearest to numerous: karpov, pedal, hvv, fanlisting, hmong, reacting, unincorporated, cotswold,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.6090 0.3444 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.5549 0.3390 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.5192 0.3375 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.4797 0.3394 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.4182 0.3379 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.5293 0.3386 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.4922 0.3405 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.4517 0.3399 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.4085 0.3380 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.4685 0.3384 sec/batch
# Nearest to not: twirl, nonviolence, fuji, valves, dernier, electromagnetism, chagall, defeating,
# Nearest to three: oscilloscope, relieved, undergoes, severed, noli, entropic, vulnerabilities, maneuver,
# Nearest to no: rerum, complications, zany, reiner, heschel, durham, herb, bessarabia,
# Nearest to however: perle, certificates, madhava, astrological, cephalopods, koyaanisqatsi, unikom, enslavable,
# Nearest to during: atypical, geologically, demolish, dat, preparation, abate, accumulations, placer,
# Nearest to between: penumbral, mideast, tojo, reconsider, kp, plundering, perjury, follicle,
# Nearest to i: mcgwire, kigamboni, unfilled, compactification, debatable, pappy, opportunistic, heechee,
# Nearest to system: updating, odore, oyster, overheat, coolidge, kudo, nhl, janeiro,
# Nearest to mean: garnets, jagged, sobriety, casings, gabriele, examine, sns, neglected,
# Nearest to paris: valuable, listings, planckian, stamps, dancehall, landmine, excised, chico,
# Nearest to assembly: bragg, minutemen, tax, bourbaki, tragic, chances, dutch, clients,
# Nearest to derived: hertford, driftwood, recurring, autocrat, roper, precedence, rubens, kandy,
# Nearest to running: vesta, genoa, httpd, estonia, helix, backed, alfredo, purpose,
# Nearest to ice: qimei, finley, shammai, junichiro, fari, casio, hyatt, mettrie,
# Nearest to shown: plenum, stanley, keeping, assorted, iberville, minimized, geocaching, poetic,
# Nearest to numerous: calligraphers, combatant, corrosive, lasting, andover, sag, chiastic, gyroelongated,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.4650 0.3435 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.4380 0.3390 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 5.4029 0.3405 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 5.3845 0.3397 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 5.3122 0.3471 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 5.3722 0.3434 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 5.4172 0.3385 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 5.3496 0.3380 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 5.3711 0.3399 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 5.3698 0.3395 sec/batch
# Nearest to not: guam, ludendorff, freikorps, substrate, novi, anchorite, palpatine, koufax,
# Nearest to three: smac, compton, ddg, immortals, holman, clausius, himmelreich, crespigny,
# Nearest to no: lexicographers, scrap, meyer, narain, scarcity, corresponded, supercontinent, sleng,
# Nearest to however: hexagonal, vitruvius, cear, obscene, hadiths, ogdoad, establish, snegur,
# Nearest to during: colliery, servius, hearne, ingots, brevet, caracalla, carpentry, euwe,
# Nearest to between: maintain, fitz, hymns, kinross, sterilization, steiner, timepieces, vichy,
# Nearest to i: rie, subtract, aborted, gimpshop, kestrel, brasil, legalistic, canceled,
# Nearest to system: handball, gentry, nicky, lovell, elapsed, coffea, mindaugas, damper,
# Nearest to mean: precursors, qazaqstan, shui, breda, nicolay, reagan, tropane, hultsfred,
# Nearest to paris: telegraphs, pug, investigated, penitent, polymerization, baffled, noncombatants, adhered,
# Nearest to assembly: cham, condemns, nonprofit, anconia, kleenex, accelerations, redfield, clown,
# Nearest to derived: eurasiatic, bravely, encode, chin, mosley, tara, michinaga, borromini,
# Nearest to running: malinche, eleventh, pray, kyrie, enforceable, maeterlinck, desktops, triangles,
# Nearest to ice: nonproliferation, nassau, bal, libre, lakshmi, tsu, axis, smo,
# Nearest to shown: sqrta, stockwell, daewoo, grows, reinforcement, objection, iuris, injury,
# Nearest to numerous: fulani, kart, ohio, asamiya, sixpence, praised, haran, specializes,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 5.3424 0.3437 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 5.2772 0.3399 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 5.3828 0.3409 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 5.3405 0.3392 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 5.3572 0.3408 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 5.2604 0.3406 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 5.2409 0.3397 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 5.2306 0.3385 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 5.2621 0.3393 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 5.2756 0.3382 sec/batch
# Nearest to not: morisot, shakers, zawahiri, eluded, knockouts, flips, scanners, hurst,
# Nearest to three: coc, caravan, dreaded, millennium, ecuadorians, verses, privatization, imaginary,
# Nearest to no: dating, fishing, cd, protesters, arianna, lute, forms, choking,
# Nearest to however: passing, propped, antibacterial, deponent, preach, othniel, clarifying, jabal,
# Nearest to during: force, coming, shuttles, endoplasmic, edible, monika, moons, electorally,
# Nearest to between: cormorants, synod, wp, dictionaries, beazley, conviction, licensees, utopia,
# Nearest to i: secretes, truth, ensured, boney, rebate, mana, pasp, georg,
# Nearest to system: mikkelson, inclusion, represent, escalate, clem, absconded, inviscid, amici,
# Nearest to mean: dyess, gaussian, sol, another, latinate, dismantled, ripe, wands,
# Nearest to paris: passim, camper, kaspar, dove, platforms, hajime, subtracting, storylines,
# Nearest to assembly: cousteau, controlled, haganah, communiqu, skin, copley, ambrosians, polonius,
# Nearest to derived: smg, maintenance, indent, smyth, predication, koestler, firing, cameroun,
# Nearest to running: gentis, favre, ghostly, encapsulated, antiquarks, gently, augsburg, assessed,
# Nearest to ice: varela, governed, deleted, lifeless, brownstone, shadowrun, ramgoolam, lithograph,
# Nearest to shown: funicular, literate, gazette, privileges, metals, legitimately, splices, jia,
# Nearest to numerous: grierson, niece, gleason, hamster, carinthia, ilmarinen, graven, baracca,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 5.2121 0.3448 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 5.2523 0.3415 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 5.2464 0.3470 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 5.2310 0.3420 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 5.1870 0.3400 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 5.1566 0.3388 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 5.1750 0.2444 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 5.1864 0.3404 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 5.0983 0.3403 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 5.1713 0.3389 sec/batch
# Nearest to not: ncv, vanier, meconium, weidenfeld, gra, sexuality, rumours, hampering,
# Nearest to three: dragon, roadmap, coordinator, lumped, oakley, ie, pantheistic, rcmp,
# Nearest to no: automorphism, moabite, sabo, deforested, syracuse, hedonistic, hardly, overlay,
# Nearest to however: metis, keiko, amal, rac, cher, misunderstood, somali, indigo,
# Nearest to during: diplomas, capitalist, censoring, celebrated, transclusion, zu, probably, nernst,
# Nearest to between: affixed, discretion, nods, peacemaker, visually, saucers, medicinal, conveyed,
# Nearest to i: cicero, huascar, scheldt, ediacara, cofactor, scrip, callsign, ambique,
# Nearest to system: pusan, historicist, albans, zoolander, ud, macau, data, englishman,
# Nearest to mean: guang, accommodating, broaden, cytokine, discipleship, abyssinia, ctor, sterility,
# Nearest to paris: denarius, neumann, marlin, porter, precipitation, neutronic, beltway, utrecht,
# Nearest to assembly: deduce, budget, unjust, substring, dodecanese, quran, skeletons, consume,
# Nearest to derived: unitas, keypad, traded, dipping, imperfectly, shrinking, apricots, metamagical,
# Nearest to running: tarantula, fraternities, exposed, pozsony, destroying, percent, dieterich, chukotka,
# Nearest to ice: driest, gaming, sightseeing, limousines, secretarial, merlot, halle, radiography,
# Nearest to shown: sparrow, joker, briefly, whatsoever, raised, minocycline, flashback, deprecating,
# Nearest to numerous: leeward, fatty, juli, kampf, sideshow, internetwork, dvds, fibrillation,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 5.1584 0.3446 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 5.1072 0.3443 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 5.1451 0.3395 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 5.1429 0.3391 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 5.1221 0.3393 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 5.0933 0.3400 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 5.1244 0.3394 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 5.1248 0.3388 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 5.0960 0.3390 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 5.0606 0.3427 sec/batch
# Nearest to not: dissatisfied, contrapuntal, iehouah, embarking, firefly, weary, krzyzewski, peacemaking,
# Nearest to three: scriptural, supremacist, lamented, blacklist, dcl, leopardi, missoula, wimbledon,
# Nearest to no: drumlins, rajk, bluescreen, bubbling, tavistock, valadon, distract, sodium,
# Nearest to however: tissue, iteration, ges, resale, mel, precision, printmaking, ragged,
# Nearest to during: stresses, qa, bronte, hesiod, latinized, mamayev, textes, successive,
# Nearest to between: removable, soissons, refrain, shipboard, vander, congress, nunn, cido,
# Nearest to i: schoolhouse, hourglass, iana, apostate, albania, yalu, frontier, online,
# Nearest to system: bridle, gloster, irreducibility, herodotus, benedictines, engine, usurping, kober,
# Nearest to mean: uncles, kepler, badges, mudslides, hallucinogens, limbo, meaningfully, northumbrian,
# Nearest to paris: juggling, hanseatic, goons, salieri, councilor, surgical, spikes, interbreeding,
# Nearest to assembly: maleev, ginsburg, ramat, ryaku, magistrates, lothar, ticket, ori,
# Nearest to derived: mithraic, access, whalers, maple, practices, eithne, demonstrative, otis,
# Nearest to running: praiseworthy, pernoud, cinematographer, motels, booths, subjection, tsarevich, dollywood,
# Nearest to ice: chips, await, heavenly, ahriman, cdma, coroners, dire, esk,
# Nearest to shown: bracelet, carotene, thunberg, submarine, incl, rafts, enter, maslow,
# Nearest to numerous: exercising, enniskillen, sex, serbo, pythian, bribing, otp, derelict,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 5.0492 0.3490 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 5.0779 0.3387 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 5.0708 0.3424 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 5.0552 0.3419 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 5.0360 0.3367 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 5.0505 0.3391 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 5.0968 0.3390 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 5.0555 0.3383 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 5.0344 0.3378 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 5.0138 0.3400 sec/batch
# Nearest to not: kinsey, jagiellonian, choke, breslau, compelling, is, gyroscopic, lovin,
# Nearest to three: superstition, stationary, clostridium, elrond, chute, archipelago, legionnaire, examination,
# Nearest to no: maw, deregulated, countrymen, manuel, corinne, sensitive, frick, owes,
# Nearest to however: gabriele, shelta, hoaxed, reputable, inundation, rriais, superiors, saber,
# Nearest to during: epitomized, appellations, felicity, derivation, pital, silmarillion, pataca, somebody,
# Nearest to between: arkansas, incited, voc, shortening, lucinschi, tori, mistaken, consecrate,
# Nearest to i: maestro, vipassana, blocking, bari, clare, converse, exploded, homelessness,
# Nearest to system: hibernate, stakeholders, unbreakable, maoism, bari, fittest, stringed, bacteriologist,
# Nearest to mean: babylonia, destroy, rapport, forlanini, trainer, suspicions, freddy, turbofan,
# Nearest to paris: southwell, reflects, gokturk, scottsdale, surging, parametric, amazigh, wrongful,
# Nearest to assembly: fux, formality, afdb, itinerant, tagliatelle, data, alumni, hgp,
# Nearest to derived: hua, deflation, legation, formulario, slay, kenesaw, mulberry, users,
# Nearest to running: sort, twists, konami, stefano, ehud, residuals, tailed, megawatt,
# Nearest to ice: antes, mustered, urine, adf, longrightarrow, ash, crimson, orser,
# Nearest to shown: oncoming, canola, satirizes, cannibalism, kassite, teammate, bedside, respecting,
# Nearest to numerous: locales, qualitative, liaison, irresponsibility, blocks, remakes, presidente, morrissey,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.9633 0.3429 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 5.0019 0.3399 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 5.0605 0.3388 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.9887 0.3415 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.9816 0.3395 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.9921 0.3401 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 5.0345 0.3401 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.9552 0.3474 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 5.0044 0.3441 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.9934 0.3375 sec/batch
# Nearest to not: garda, renderer, moose, contrabassoon, champollion, billion, genuine, epiphanes,
# Nearest to three: jiangxi, refuel, shortcut, maintainers, avm, glycosylation, tanks, pigeons,
# Nearest to no: drava, engle, vitally, noche, robins, observant, spiritual, reciprocal,
# Nearest to however: kan, rubin, unveils, sfor, curiosities, washing, northrop, medieval,
# Nearest to during: dudley, repose, vitae, donato, centro, dorris, fabric, dares,
# Nearest to between: lightest, broccoli, abiding, warszawa, pure, togethers, tradeoffs, vasari,
# Nearest to i: zealot, ayer, haute, argonauts, roundhouse, dredd, syndromes, converging,
# Nearest to system: armitage, ghetto, premiership, patriarchy, thirst, guatemalan, chastisement, conquer,
# Nearest to mean: appropriately, harry, gehenna, fusion, arndt, hewn, pbk, cornucopia,
# Nearest to paris: heart, guillaume, temp, serf, sinhala, xiong, squat, tempos,
# Nearest to assembly: disembodied, swallow, landmass, plazas, viktor, create, hut, identifications,
# Nearest to derived: skier, forms, lifelike, arrangers, simplify, sy, impressionable, bury,
# Nearest to running: huntress, obligation, fc, pacifism, clansman, sensations, eiermann, symbolic,
# Nearest to ice: irregularity, darshan, ranching, excessively, pericles, monochrome, octavio, chauncey,
# Nearest to shown: dimensions, lycus, nicknames, vented, hst, bridging, iudaea, yoshitaka,
# Nearest to numerous: reginald, farouk, pastiches, cuanza, dimbleby, tey, rahxephon, carnatic,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.9950 0.3457 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.9903 0.3407 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.9505 0.3389 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.9496 0.3382 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.9443 0.3388 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.9710 0.3394 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.9125 0.3378 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.9251 0.3410 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.9796 0.3382 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.9532 0.3384 sec/batch
# Nearest to not: ircd, sparking, dogged, nsg, mage, pq, articulatory, pretence,
# Nearest to three: flanker, quantifiable, vishnu, mercantile, enforce, montague, anzus, affaires,
# Nearest to no: eligible, mcbeal, graffiti, bardic, ksh, evangelische, jaco, purchaser,
# Nearest to however: cottingley, arriba, perfumes, seabird, powell, devry, piracy, preclear,
# Nearest to during: ethnography, angelina, blackburn, torino, catalhoyuk, regal, peroxy, video,
# Nearest to between: nest, banat, fatalism, cathedra, rfloor, waterways, songwriters, botanical,
# Nearest to i: ask, happens, troilus, performed, revisionists, vainly, fibrosis, somoza,
# Nearest to system: cuyp, warriors, underlying, plugging, whereof, scout, maskhadov, farmer,
# Nearest to mean: verses, apocalypses, gigabyte, normal, barri, necklace, ftl, bylaw,
# Nearest to paris: reset, oba, stray, kooning, navies, migratory, alveolo, keep,
# Nearest to assembly: sexuality, hedley, evoluon, bacilli, uppercase, tablets, moron, newt,
# Nearest to derived: wisdom, marta, reactance, enriched, pyrenean, clerks, attire, pontificia,
# Nearest to running: mems, polyalphabetic, glove, hanover, nuclides, prohibitive, enrolls, resignations,
# Nearest to ice: gules, rivi, homeostasis, chess, midpoint, retaken, shalem, mi,
# Nearest to shown: pu, debut, apap, gondwana, company, classicism, khtml, mordant,
# Nearest to numerous: malthus, neuro, poisons, gillmor, pericardium, easters, rebus, gundahar,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.9139 0.3435 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.9040 0.3453 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.9215 0.1491 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.9271 0.3401 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.9059 0.3452 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.8652 0.3447 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.9159 0.3411 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.8653 0.3385 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.8689 0.3393 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.9043 0.3383 sec/batch
# Nearest to not: functionalist, phish, jamaican, emory, rooming, proteome, silently, gochujang,
# Nearest to three: neutralization, undercroft, boys, fallout, embarks, dollywood, resourceful, atrocity,
# Nearest to no: legitimacy, unitar, capybaras, dared, analogical, addis, arbitration, percussionist,
# Nearest to however: cvn, thessalonians, grassy, amerigo, beos, careless, dynamical, reagent,
# Nearest to during: idomeneus, deletes, funnies, theological, kapoor, techstep, ztt, blizzards,
# Nearest to between: monthly, kong, chickenpox, genital, halide, convictions, megabyte, overhauled,
# Nearest to i: recombine, fruity, censor, celestines, bn, lear, troubling, bremer,
# Nearest to system: ssp, piety, clonazepam, eridanus, carcasses, voss, rathaus, pool,
# Nearest to mean: tipping, johansen, hacker, hecate, missiles, gs, brownstone, sopranos,
# Nearest to paris: serenity, micky, scholarships, jnana, lag, germani, grillet, dreams,
# Nearest to assembly: llar, pata, msnbc, iconoclastic, expectancies, klaipeda, ascanian, nasi,
# Nearest to derived: furies, drip, pid, yell, cyborg, tub, secombe, aurora,
# Nearest to running: haldeman, gerson, imprison, prefectures, formalisms, slots, muses, elsinore,
# Nearest to ice: wordperfect, squids, transliterated, pedophilia, negativity, nagasaki, genius, toland,
# Nearest to shown: bum, saviola, exited, whither, valvular, adolescents, indiscretions, lieder,
# Nearest to numerous: shuffled, hydro, speciesism, goa, intimate, amidah, exit, uplink,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.8895 0.3417 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.8789 0.3390 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.8921 0.3386 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.9146 0.3388 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.8946 0.3381 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.8869 0.3378 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.8555 0.3363 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.8608 0.3387 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.8607 0.3384 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.8791 0.3381 sec/batch
# Nearest to not: cvbg, bint, utilitarians, moxibustion, yogyakarta, recover, hearing, extortion,
# Nearest to three: troughton, colbert, vb, gabab, weishaupt, portrayed, median, photovoltaic,
# Nearest to no: maths, wmd, turret, wahhabi, destabilized, ani, utamaro, donny,
# Nearest to however: slurs, neutralizing, technicality, kilmer, leges, oxbridge, magnesia, resist,
# Nearest to during: naomi, elephantine, chiefdoms, scenic, patrician, gradients, aix, ignacio,
# Nearest to between: enclaves, bluetooth, mandamus, geocentric, blurs, muscovy, antipsychotic, deserters,
# Nearest to i: altitude, saviola, pantone, constituting, llc, pital, emanuel, mammalian,
# Nearest to system: endoplasmic, afterburner, jarrah, displayed, ethnically, augie, lateral, sumo,
# Nearest to mean: blended, sdi, lawsuits, destined, rdenas, asians, maryam, porco,
# Nearest to paris: baywatch, microscopes, bloom, jia, duffy, pieces, leprosy, peaks,
# Nearest to assembly: joseon, ablaut, eubacteria, arteries, overdose, caapi, furies, forall,
# Nearest to derived: latter, ligature, valve, confined, waid, postwar, bragr, overlaps,
# Nearest to running: ingesting, longbow, angel, laplace, breathy, qualifier, skyscraper, gravity,
# Nearest to ice: methylation, siegel, theorized, manors, yuri, hurl, measuring, cinder,
# Nearest to shown: pidgin, shutdown, tiered, generalissimo, dennis, uninteresting, kubrick, quickening,
# Nearest to numerous: helios, parsers, aspirations, denominator, deadites, world, wachowski, critics,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.8383 0.3429 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.8384 0.3393 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.8623 0.3467 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.8361 0.3414 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.8429 0.3420 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.8367 0.3385 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.8565 0.3395 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.7952 0.3382 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.9129 0.3401 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.8049 0.3401 sec/batch
# Nearest to not: microorganisms, manic, lippisch, medio, lydon, ruck, glaciations, leaning,
# Nearest to three: torlakian, danceable, yahweh, videotaped, spartacus, lillard, mica, waal,
# Nearest to no: subspecies, wawel, conceptualize, greta, incorporation, lively, dreamers, binitarians,
# Nearest to however: ross, sociale, backer, significant, leeves, postmodernism, sloping, clutching,
# Nearest to during: scholarly, horrific, theurgy, asset, solve, arabic, skeptic, meconium,
# Nearest to between: riesz, multidimensional, wolves, wire, eisler, similarity, pics, blacklisting,
# Nearest to i: excalibur, fortresses, carefully, wretch, quarks, crypt, mathieu, couturat,
# Nearest to system: generalitat, nernst, heros, bertolt, slaughter, faxing, protein, accorded,
# Nearest to mean: crumbled, skara, lookahead, celebration, comb, construct, haihowak, carib,
# Nearest to paris: posses, traveler, intercontinental, dogged, lockwood, hodgkin, fsln, betting,
# Nearest to assembly: struct, evangelium, theophylline, aleksandrovich, foerster, isabella, court, oligocene,
# Nearest to derived: home, mealy, landa, neil, eifel, iotation, polysaccharide, frustrated,
# Nearest to running: eider, roark, wiggle, postulates, interferometer, correction, vulcan, schlick,
# Nearest to ice: corinne, hidalgo, aq, shied, displeasure, bombard, preoccupation, wikipedia,
# Nearest to shown: evangelicalism, sio, ballplayer, iain, naturae, zadar, surge, ottomans,
# Nearest to numerous: wilderness, valera, episcopalians, manipulates, guildenstern, loved, discriminant, gj,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.7981 0.3423 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.8340 0.3396 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.8379 0.3394 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.8152 0.3402 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.8262 0.3381 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.8760 0.3381 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.8290 0.3406 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.8296 0.3404 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.7968 0.3377 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.8015 0.3399 sec/batch
# Nearest to not: grey, theologian, injective, subregion, pleiades, stonehenge, erect, ferrari,
# Nearest to three: earthen, openoffice, rebuilt, cutlery, grok, herold, conservationist, semester,
# Nearest to no: austerity, djing, darryl, grimmett, vulture, mimsy, websites, employees,
# Nearest to however: soldiery, leguminous, dhea, quagga, blas, chaos, kidnappers, belshazzar,
# Nearest to during: steiner, nonempty, hokkaido, oscillate, catechetical, leopard, exemplifies, infamous,
# Nearest to between: runoff, mips, hitomaro, seaborg, mixtec, princess, symbolising, racecar,
# Nearest to i: sommers, hansa, levitated, wiseman, cumbersome, carthage, weaned, cadence,
# Nearest to system: lupin, amit, preparatory, skilled, marsupialia, wftu, endymion, handed,
# Nearest to mean: fluorescence, oktoberfest, maori, sinai, suddenly, winged, garp, chechen,
# Nearest to paris: gai, luca, clift, perhaps, modulation, hexer, confederacy, hostility,
# Nearest to assembly: inadvertantly, hihat, nominal, biblical, theodoret, heretical, woodland, kahan,
# Nearest to derived: polanyi, kathleen, irix, eberhard, acknowledged, shahis, bhutto, destroyer,
# Nearest to running: karoline, fenrir, rasterization, star, najd, parent, radial, anecdote,
# Nearest to ice: benghazi, powerful, alveolo, kurtz, piled, corrientes, adolphe, numismatics,
# Nearest to shown: plasticizers, determinant, peopled, architect, metropolitans, markschies, bergson, lame,
# Nearest to numerous: rainstorm, gazpacho, pellucidar, chamberlain, doi, upriver, kerk, livio,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.7768 0.3504 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.8480 0.3417 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.7962 0.3381 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.7952 0.3388 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.8301 0.3400 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.7843 0.3382 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.8212 0.3382 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.7687 0.3407 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.8121 0.0542 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.8279 0.3469 sec/batch
# Nearest to not: af, wojty, micron, holders, lukoff, pskov, outstretched, twofold,
# Nearest to three: purposes, decay, ionization, oed, proscribe, encephalopathies, viral, odyssey,
# Nearest to no: chap, session, padre, tangible, ehud, isotropy, jenkins, ladd,
# Nearest to however: lynne, defender, olympic, clair, reportedly, romanian, ue, bhishma,
# Nearest to during: toolbox, wilhelmina, donnell, ulcer, baghdadi, extremophiles, retiring, ethnological,
# Nearest to between: gelasian, gather, thorough, clamps, volition, iodides, junkers, linkage,
# Nearest to i: druidic, trademarks, planning, sinner, convective, zanjeer, arsenate, almsgiving,
# Nearest to system: defensible, subscriptions, sentence, publish, shaman, introductions, stupa, adhd,
# Nearest to mean: flint, defeat, ediciones, spanning, roshan, valderrama, require, polo,
# Nearest to paris: overextended, dewan, starter, outburst, punctuated, bluffs, stringy, pandora,
# Nearest to assembly: equidistant, obese, uncanonical, disallow, cropland, eilat, disuse, odilo,
# Nearest to derived: terri, rickover, tiff, demonstrators, equine, stressing, schoolchildren, laura,
# Nearest to running: kambojas, instance, lashes, recalculated, satem, turner, streisand, sonority,
# Nearest to ice: masted, aeon, hadrian, russification, marguerite, constantin, assets, mie,
# Nearest to shown: prescribed, trisha, coots, prove, literacy, fraternity, unb, primogeniture,
# Nearest to numerous: macaria, proudly, torres, hoarse, peart, resolutely, inverse, hyaena,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.7974 0.3437 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.7464 0.3402 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.7908 0.3386 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.7578 0.3382 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.7826 0.3409 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.7982 0.3382 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.7956 0.3378 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.7788 0.3438 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.7581 0.3429 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.8257 0.3402 sec/batch
# Nearest to not: modena, dn, iconoclastic, breakdancer, grapevines, hao, tarragona, overgrowth,
# Nearest to three: picker, adenylate, eysteinn, pople, paraguay, giancana, nascent, zimbardo,
# Nearest to no: survive, redwoods, kiosks, conectiva, usn, marking, tiran, suspicions,
# Nearest to however: widdecombe, ultimo, liters, mcnamara, ajmer, cvd, troja, oshawa,
# Nearest to during: ddt, pictish, hurt, unregistered, buzzcocks, pontryagin, hospital, incredible,
# Nearest to between: dann, syrup, reachable, perjury, elis, prosecutor, assamese, invalid,
# Nearest to i: apicomplexa, uses, forgetful, muscovites, procopius, almanac, anaheim, spamming,
# Nearest to system: mythologies, kirwan, ridley, jagan, lansdowne, austin, robustness, shakyamuni,
# Nearest to mean: baseketball, rehearsal, partially, mattered, marathon, hague, achromatic, bertha,
# Nearest to paris: stahl, sibley, electronically, calibrated, none, fa, wetter, childhood,
# Nearest to assembly: pressurised, islanders, scott, indemnity, uris, building, ous, position,
# Nearest to derived: cabinets, ccta, taur, sheepdog, abn, nkvd, navarrese, subjugated,
# Nearest to running: violin, guiding, lagoon, supergirl, sergipe, detentions, kio, franco,
# Nearest to ice: skis, shit, caston, legalize, postpositions, rendezvous, salman, brancusi,
# Nearest to shown: fretted, conferred, contre, brie, contrivance, appearances, chamber, elihu,
# Nearest to numerous: abundant, dodecylcyclobutanone, saddened, cernunnos, aorist, comrie, agitating, ugc,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.7903 0.3462 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.8045 0.3400 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.7578 0.3398 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.7496 0.3378 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.7698 0.3393 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.7587 0.3376 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.7649 0.3384 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.7469 0.3385 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.7631 0.3397 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.7679 0.3379 sec/batch
# Nearest to not: originates, dhole, miracleman, coat, fired, shipman, damien, corrects,
# Nearest to three: dione, learned, coordinate, composting, mtsho, decrypts, ixian, cinematic,
# Nearest to no: emigrant, banacek, gokturk, miso, certainly, transfiguration, condorcet, fulfill,
# Nearest to however: ramone, dominic, chunnel, housing, awacs, acronym, keeps, youngest,
# Nearest to during: cosy, longest, nowell, sweetener, comit, prayers, idb, flunitrazepam,
# Nearest to between: luxemburg, innocents, satirize, knoll, secombe, stranger, brookside, imperial,
# Nearest to i: residing, chack, tipped, relapsed, chooses, fabio, airshow, hbox,
# Nearest to system: loeb, separately, interrupts, banquet, goalscorer, mcknight, carleton, noncommercial,
# Nearest to mean: informatics, item, capillary, atmospheres, sudetenland, crudely, moving, stationed,
# Nearest to paris: bradford, dimethyl, husayni, crisscrossed, belsen, bitstrings, alexandrovna, faulty,
# Nearest to assembly: marshland, fidonet, finalized, biking, nightclubs, kazak, refrain, eastward,
# Nearest to derived: feasting, safeties, invulnerable, yyyy, nihilo, sdlp, entendre, haughey,
# Nearest to running: ashkenazim, validated, vest, equaled, northcote, gaba, josephine, endothermy,
# Nearest to ice: emf, kekkonen, levitt, interconnect, perilous, solicit, habitability, bofors,
# Nearest to shown: competitive, friedlander, houston, tedious, stripper, scoped, hants, adonis,
# Nearest to numerous: katangan, caliphates, ph, lobos, raporto, volume, kannapolis, stuntman,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.7539 0.3428 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.7658 0.3386 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.7764 0.3376 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.7299 0.3378 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.7624 0.3394 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.7702 0.3464 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.7304 0.3418 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.7421 0.3411 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.7490 0.3390 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.7540 0.3389 sec/batch
# Nearest to not: unoccupied, anodes, impacted, synthesizers, widening, extraneous, darn, pharisee,
# Nearest to three: deserts, prevent, bogomils, por, griswold, mamma, lenin, jug,
# Nearest to no: yorkshire, quintus, mayor, populations, magnifying, niccol, convexity, encircles,
# Nearest to however: nau, unsurprising, slobodan, kosmos, longa, axum, mornay, barrel,
# Nearest to during: shuttle, dalhousie, stationed, commentarii, westchester, haori, neuropathy, kirghiz,
# Nearest to between: strips, nau, kenilworth, devlin, entrepreneurs, showa, brezhoneg, trinidad,
# Nearest to i: inventiveness, rusting, editing, johnsen, oldenburg, monsoonal, magnificently, dinoflagellates,
# Nearest to system: tuxedo, decennial, geminated, rostov, wardens, alster, chokes, geocities,
# Nearest to mean: sse, grammarian, gigabytes, ca, proprietor, reinstating, borrowing, stateside,
# Nearest to paris: lanky, datasets, geared, injury, argyle, rectangles, stabbed, janus,
# Nearest to assembly: beltway, gur, lagging, microscopic, hoaxed, seams, peloponnesus, arsenio,
# Nearest to derived: superhero, chapman, velars, shooters, enya, ck, yupik, gouverneur,
# Nearest to running: antagonism, fuze, guybrush, clunies, leased, outranks, germanicus, feller,
# Nearest to ice: pizzicato, zeitung, bronzino, precludes, walt, descendants, mestizos, conurbations,
# Nearest to shown: janitor, aquileia, syracuse, singularities, anjouan, glc, dench, alimony,
# Nearest to numerous: circuitry, honorum, zona, oeuvres, lexington, enchanting, starting, surges,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.7324 0.3431 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.7837 0.3382 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.7504 0.3374 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.7430 0.3408 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.7335 0.3421 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.7310 0.3392 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.7003 0.3396 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.7514 0.3391 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.7382 0.3376 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.6897 0.3371 sec/batch
# Nearest to not: athene, gmelin, incur, dostoyevsky, recursive, bunghole, koi, maudslay,
# Nearest to three: grouse, plein, hindustan, flaws, casual, displacing, akshara, astute,
# Nearest to no: inherent, acceptance, shockley, forgery, caterpillar, diurnal, shahi, tarquinius,
# Nearest to however: glance, televizija, devotions, neurologists, laura, vallabhbhai, camden, hao,
# Nearest to during: vague, monoxide, carbohydrates, clipped, crowds, abilities, adaptor, iberian,
# Nearest to between: fully, luttwak, gertrud, chairperson, spire, complying, gibraltarians, centerpiece,
# Nearest to i: yetzirah, lesund, shapiro, radiohead, nmt, blasphemy, curving, appliances,
# Nearest to system: calculable, sandilands, schottenheimer, character, thysanoessa, boggs, frequent, forcibly,
# Nearest to mean: kingship, giraffe, sentries, compliant, tcm, emigrate, jharkhand, rosebud,
# Nearest to paris: utah, peacock, boltzmann, gatwick, khazaria, slalom, recognizer, dimona,
# Nearest to assembly: disruption, catches, incapable, wchl, antitrust, ransoming, lawyer, ronnie,
# Nearest to derived: umno, correction, chanced, anticipate, virginals, companionship, ridgeland, reticent,
# Nearest to running: maize, melville, triiodothyronine, astronaut, galba, caballero, ayman, eckert,
# Nearest to ice: joan, chorded, routines, rsta, malloum, edicule, dear, ippon,
# Nearest to shown: bavarii, vincennes, finagle, decolonization, positive, windfall, militarized, charcoal,
# Nearest to numerous: unguarded, invaded, nootka, mohamad, terre, eider, osiander, pledging,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.7500 0.3424 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.7394 0.3388 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.7385 0.3428 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.7149 0.3463 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.6933 0.3386 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.7463 0.3003 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.7222 0.3393 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.6944 0.3400 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.7094 0.3388 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.7016 0.3389 sec/batch
# Nearest to not: skater, enshrined, posits, oratio, rabban, heroics, developments, jeffreys,
# Nearest to three: kernighan, redmond, rebuked, updike, missy, coldly, grissom, vanier,
# Nearest to no: exhibited, realizing, submit, dm, ndel, demonology, bajan, mechon,
# Nearest to however: searched, universitario, brecht, formulas, romero, mussar, bight, jlp,
# Nearest to during: vibrant, jamaicans, overkill, frustrated, phine, impeach, taklamakan, klara,
# Nearest to between: bulwer, graphically, linguistics, intermingle, magnolia, henslow, hol, spores,
# Nearest to i: inductee, favorites, oberlin, guarantor, rpg, disparaged, patrons, truism,
# Nearest to system: beaten, lode, archons, bactrian, rascal, lumped, actus, tocantins,
# Nearest to mean: jealous, aviators, kimball, lavey, ilayaraja, ser, dommel, keywords,
# Nearest to paris: rabbah, twente, focused, msc, bestowed, corry, gni, rhodes,
# Nearest to assembly: due, tetanus, exclaimed, willys, refectory, racine, scramble, detect,
# Nearest to derived: shah, devarim, vv, theistic, rigorously, myanmar, hides, mailer,
# Nearest to running: brumaire, baggage, gaseous, sui, photosphere, pulpit, stendhal, ladykillers,
# Nearest to ice: clamps, confocal, paternalism, chosen, portrayal, crease, sichuan, accompanied,
# Nearest to shown: cursing, beetle, stubborn, steepest, alliterative, incidents, henslow, pilgrims,
# Nearest to numerous: smallest, pardon, bab, haec, quests, archdiocese, failings, neg,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.7015 0.3446 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.7185 0.3388 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.7119 0.3378 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.6927 0.3391 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.6916 0.3379 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.7074 0.3380 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 4.7231 0.3382 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.7022 0.3387 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 4.7102 0.3385 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.6888 0.3366 sec/batch
# Nearest to not: zucchini, omphale, maji, bear, hologram, islamists, derbyshire, anarcha,
# Nearest to three: genuinely, mirth, anglophone, berliners, amputee, rookie, bastnasite, comerica,
# Nearest to no: quae, brl, fax, draw, chesterfield, plano, disarmament, assert,
# Nearest to however: titled, informally, nite, jaxa, mandragora, dkp, hunyadi, seafaring,
# Nearest to during: pranksters, eldr, istv, compl, bengalis, woodcut, christadelphians, transnational,
# Nearest to between: diced, catering, stoney, fusing, toon, inoculate, polyester, cat,
# Nearest to i: centered, tei, dorset, insulted, schr, mohandas, beard, galla,
# Nearest to system: lobos, misses, eventually, wace, undeserved, modifiers, posture, cortes,
# Nearest to mean: incest, patrons, ski, concise, psychosis, propane, coloured, toolbar,
# Nearest to paris: theater, delia, believers, seljuk, lite, stoves, enda, spite,
# Nearest to assembly: slowdown, shays, theoria, guti, ibs, congruent, officialdom, fgc,
# Nearest to derived: cease, quoted, alomari, dahlgren, torgau, acadians, headstrong, tishri,
# Nearest to running: signetics, ellen, outwit, greetings, kamikaze, grinder, ambulatory, medes,
# Nearest to ice: elrond, apr, newspaperman, bah, gemological, colored, handsomest, mabon,
# Nearest to shown: seabury, partisan, apoptotic, ecclesiastics, renewable, wackyland, monarchy, corral,
# Nearest to numerous: spore, immanent, pp, monolith, udv, lapland, continence, braunschweig,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.6872 0.3489 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.7043 0.3432 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.6919 0.3382 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.7144 0.3395 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.6928 0.3377 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.7228 0.3376 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.6953 0.3388 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.6834 0.3389 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.7079 0.3386 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.6985 0.3380 sec/batch
# Nearest to not: dielectrics, attorney, arduous, floods, ptah, shahade, valproic, centauri,
# Nearest to three: cigarette, presumably, fitzgerald, raises, marksmanship, featuring, platt, fallback,
# Nearest to no: reconciling, poorest, fauntleroy, locus, arbuthnot, yhwh, tier, gallantry,
# Nearest to however: blaxploitation, lal, clearances, bolsheviks, leaflets, subhash, hada, laboriously,
# Nearest to during: curbed, kylie, eleazar, szolnok, preparation, delicately, albrechtsberger, microorganisms,
# Nearest to between: westbound, minestrone, dipping, isomer, kortrijk, kidnapping, locomotive, nederlandse,
# Nearest to i: ferguson, octopus, systemic, polycarp, polling, regum, insoluble, styles,
# Nearest to system: fusiliers, eps, laborer, maurizio, portmanteaus, exactly, diffused, fet,
# Nearest to mean: herat, caesar, arcadius, dao, petropavlovsk, uncertainty, normally, depalma,
# Nearest to paris: tableaux, peleliu, incapacity, martial, vpn, uneconomic, silt, tetragrammaton,
# Nearest to assembly: commedia, inez, klaus, theater, heraclitus, vise, gottschalk, venerate,
# Nearest to derived: prerequisites, alexanderplatz, lymph, chupacabras, marksmen, eyelids, prompted, monterrey,
# Nearest to running: taxonomically, macquarie, frustrated, complacent, benchmarking, surgeries, prejudice, elihu,
# Nearest to ice: tishri, villain, kalam, thera, absorbs, cetaceans, eridanus, riaa,
# Nearest to shown: molloy, mane, enharmonic, coleman, cca, maleficarum, sheik, mishnah,
# Nearest to numerous: foremost, blackwater, pathogenic, lindsey, carcass, corning, spans, concerning,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.6935 0.3445 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.6808 0.3388 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.6675 0.3373 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.6959 0.3391 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.6884 0.3413 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.6935 0.3386 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.6711 0.3379 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.6939 0.3398 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.7122 0.3442 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.7050 0.3419 sec/batch
# Nearest to not: galton, dmg, bergomi, vojvodina, battering, domitius, hermeneutic, citrate,
# Nearest to three: distributing, cfl, mysteriously, affix, medan, vilas, kamchatsky, misskelley,
# Nearest to no: macaria, assistants, ik, awakenings, cursory, alferd, natural, epigr,
# Nearest to however: mountjoy, contending, compressed, harbors, neuropsychology, millimeters, ulrike, kilometres,
# Nearest to during: cotopaxi, subverting, tranquility, claimed, archbishop, apes, odysseus, philibert,
# Nearest to between: incumbent, proofing, edwards, choreographies, bd, mehemet, stews, yaz,
# Nearest to i: pbsuccess, tora, petty, coup, fragility, designate, irregularities, asymptotic,
# Nearest to system: firmus, judgement, boz, harrier, geysers, devasting, dialects, assume,
# ...
# Nearest to shown: musculature, pomp, certifying, gush, engset, makarios, comrade, spence,
# Nearest to numerous: undesirables, deflation, columbo, liver, iskcon, pentateuch, folio, falklands,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.6007 0.3446 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.5713 0.3391 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.5903 0.3383 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.5811 0.3397 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.5720 0.3431 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.5711 0.3430 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.5923 0.3387 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.5650 0.3379 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.5721 0.3382 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.5719 0.3425 sec/batch
# Nearest to not: jewell, podiatric, remotely, manifestos, magneto, born, sais, atapi,
# Nearest to three: juliane, amniotes, galante, land, broadened, questioned, eisner, vacuum,
# Nearest to no: noonan, polycarp, paul, chats, shaikh, electroplating, hotham, guises,
# Nearest to however: bubiyan, unforgiving, ragenfrid, steer, blasphemous, barges, bilayer, odour,
# Nearest to during: divinorum, answered, noone, prefered, baraka, morrigan, ifs, fayed,
# Nearest to between: mogadishu, eftpos, chick, decapitated, stereocenter, revulsion, photographed, unharmed,
# Nearest to i: dentition, villanueva, ftc, forcetoc, caracas, pdm, accu, universitat,
# Nearest to system: csc, journeymen, hotter, buenos, arundel, sorcery, fool, disbelieved,
# Nearest to mean: steiner, brahms, fcc, dtft, back, extract, hinayana, wd,
# Nearest to paris: greece, derivation, dung, pharmacist, javelin, prakash, consolidated, varicella,
# Nearest to assembly: unusual, forty, folkloric, gua, synthesize, syntactic, absinthe, brightly,
# Nearest to derived: multitudes, salo, constructible, peach, within, accentuated, lyndon, socket,
# Nearest to running: workability, plateaus, wa, dystopia, hypothyroidism, lackluster, qoheleth, degenerated,
# Nearest to ice: astroturf, lytic, breathed, ramsay, lilongwe, accede, runes, snowmen,
# Nearest to shown: ruins, glamorous, lidocaine, kusakabe, headland, interbellum, yak, shattered,
# Nearest to numerous: peete, osiander, rimfire, midas, ties, ghibellines, insert, bub,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.6047 0.3440 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.5668 0.3390 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5787 0.3383 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.5906 0.3376 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.5774 0.3420 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.5920 0.3413 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.5639 0.3391 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.5809 0.3400 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.5947 0.3387 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.5856 0.3391 sec/batch
# Nearest to not: shunters, run, ivanov, cinquain, fushimi, carbides, banishment, gigo,
# Nearest to three: orexin, repressive, subtitle, mujahedeen, ay, sharkey, frf, observer,
# Nearest to no: mackaye, kamala, dictatorial, shahnama, entertained, lactose, molded, worms,
# Nearest to however: romantically, disagreed, bashir, francois, chaotic, forgo, salvaged, maslow,
# Nearest to during: statisticians, burgesses, insertafter, biochemical, denunciation, ferreira, boomers, advisory,
# Nearest to between: shelling, examined, muons, rmaf, weighed, camra, airbases, playa,
# Nearest to i: conservatorio, brabham, mus, cavalier, spectacled, alligator, biblia, naturals,
# Nearest to system: raleigh, vigilant, dictator, hypocrisy, ales, amplifier, emigrants, socio,
# Nearest to mean: dma, extracts, diluted, couper, qualified, notwithstanding, modernist, flies,
# Nearest to paris: manu, hus, can, negri, gallus, sufi, merz, window,
# Nearest to assembly: stamford, lusthog, filtered, shulkhan, buckley, fortifications, perennially, pickguard,
# Nearest to derived: joaqu, abaci, teapot, bicycle, practicing, razed, brava, borda,
# Nearest to running: delray, btr, corleone, equalization, theodor, es, luxor, pkzip,
# Nearest to ice: inwards, correlate, esarhaddon, kane, accuse, nyx, kris, pure,
# Nearest to shown: supercharged, guyana, depalma, budapest, pounding, deleting, senado, anthemius,
# Nearest to numerous: nationals, splitflag, shortwave, serts, ree, websphere, agust, akademia,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.5627 0.3403 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.5643 0.3366 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.5891 0.3487 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5754 0.3388 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.5821 0.3385 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.5714 0.3415 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.5782 0.1625 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.5609 0.3418 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.5638 0.3396 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.5566 0.3403 sec/batch
# Nearest to not: occultism, cyclops, typhoons, enshrine, zal, woodwinds, yerevan, camouflaged,
# Nearest to three: overtraining, holyoke, broadcasted, inflicted, rsta, rigel, hypostasis, carpal,
# Nearest to no: willa, unannounced, odbc, beaumont, pharaoh, dunsany, riotous, witches,
# Nearest to however: freund, culver, lynching, lakeland, schizophrenia, dalet, mace, psalm,
# Nearest to during: rhetorically, cessation, ancients, winchell, besicovitch, parsimonious, erasmus, amazonite,
# Nearest to between: cheat, mahabharat, catherine, subclasses, ciconiiformes, olivia, tenured, lagrange,
# Nearest to i: machete, mapuche, colm, spoons, monrovia, option, cavities, carabineros,
# Nearest to system: unrefined, his, nationalist, mbe, chack, kosmos, watchman, substitutes,
# Nearest to mean: ironworks, mangaka, elmira, hibernation, nontraditional, bitchx, pursuits, hurrians,
# Nearest to paris: jerry, freas, regenerate, qubit, cuteness, multimate, spruce, funerary,
# Nearest to assembly: emulsions, simone, leroux, ledyard, sponge, portrayal, brod, earning,
# Nearest to derived: kzinti, ringgit, blackwell, paths, voronin, lavender, hirobumi, squat,
# Nearest to running: kokhba, krey, msp, speculating, mauled, superconductors, atypical, strawson,
# Nearest to ice: magnetism, grosse, concord, floccinaucinihilipilification, dioxin, conspire, prefetch, briefcase,
# Nearest to shown: putsch, plenty, prosaic, electronegative, inert, partements, bonzos, rishi,
# Nearest to numerous: everton, nagaoka, patkai, logograms, starships, prestwich, seti, liturgics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.5723 0.3426 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.5615 0.3384 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.5942 0.3387 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.5873 0.3394 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.6015 0.3389 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.5565 0.3393 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.5776 0.3387 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.5964 0.3385 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.5882 0.3383 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.5799 0.3389 sec/batch
# Nearest to not: translators, evaluating, inertness, hogg, emory, frankenchrist, repressed, nonverbal,
# Nearest to three: soundtrack, usaid, busoni, vili, later, ece, plaguing, aerosol,
# Nearest to no: wildstorm, provers, beatified, panic, galahad, showman, bratislava, biscuits,
# Nearest to however: eka, ruinous, bfa, redevelop, spatiality, dinitrogen, politics, aelius,
# Nearest to during: lagers, syrians, inflexible, rag, holomorphic, cheng, wherein, stanislavski,
# Nearest to between: cumberland, lobe, masques, choices, implicating, marathon, nonaligned, tenuous,
# Nearest to i: passage, juniors, lars, revisionism, hanjour, duluth, autopsy, judoka,
# Nearest to system: jak, interlingua, atlanteans, mulattos, lemmy, stalactites, dawn, mic,
# Nearest to mean: mutual, esd, memoir, kwaidan, cukor, etna, beery, plume,
# Nearest to paris: morden, modeled, futuristic, safavid, nickelodeon, tupi, circumcise, reloading,
# Nearest to assembly: interferometer, regolith, isotopes, wrexham, myrtle, enchanter, armin, marwan,
# Nearest to derived: kickboxer, gaseous, hauling, credo, poirot, note, broadcasts, clicked,
# Nearest to running: mcdonough, autism, lonsdaleite, barzani, tropics, cues, tranquillity, removals,
# Nearest to ice: vall, townhouse, julius, safed, frightening, temair, stale, rebate,
# Nearest to shown: pegmatite, award, clinch, rod, gazelle, coinciding, bran, sensations,
# Nearest to numerous: optimize, crying, octavia, stefani, maule, dk, gracen, thorne,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5767 0.3508 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.5609 0.3411 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5594 0.3386 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.5661 0.3388 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.5568 0.3378 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.5754 0.3401 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.5867 0.3381 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.5674 0.3385 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5602 0.3371 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.5726 0.3409 sec/batch
# Nearest to not: elrond, preventable, gabriel, kilpatrick, technologies, peptides, zseries, elway,
# Nearest to three: sydney, terrorist, infix, netware, breakers, seigneurial, leaked, edith,
# Nearest to no: gondor, enzyte, miming, openbsd, carps, prepubescent, circumnavigation, datura,
# Nearest to however: nonce, vittorio, marinetti, domiciled, journalists, eia, conjuring, pocket,
# Nearest to during: croix, razi, blessing, forlorn, smalltalk, psionic, hordes, matriculated,
# Nearest to between: threshold, regal, sayed, despise, sopron, ancillon, binders, walls,
# Nearest to i: forced, hallucinations, reykjav, tranquillity, crony, conceals, daughters, garbage,
# Nearest to system: resolution, polygamist, monarchy, aired, songwriter, without, ammoniac, postprandial,
# Nearest to mean: devi, greatness, detractors, tridentine, converse, lear, dubois, vaccinium,
# Nearest to paris: newt, siding, decent, zorn, betrays, jani, technetium, revolted,
# Nearest to assembly: reneged, movements, ablaut, citizenship, inukshuk, landlord, bulges, cubic,
# Nearest to derived: escalation, conclude, ocular, hajime, aegis, interlaced, laramie, inattention,
# Nearest to running: plebiscite, halifax, anode, informational, satrapies, mcmahon, poul, incidents,
# Nearest to ice: condemned, detergents, beech, fruiting, revoke, punching, zionist, penguin,
# Nearest to shown: proficiency, fascio, haughty, spo, glow, purification, fade, liquidate,
# Nearest to numerous: notorious, reels, besieged, scallop, nebuchadrezzar, versatile, divorcee, ressentiment,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5446 0.3445 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5426 0.3369 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.5822 0.3387 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.5468 0.3375 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.5592 0.3375 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.5619 0.3389 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.5737 0.3384 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5622 0.3447 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.5643 0.3442 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.5844 0.3374 sec/batch
# Nearest to not: duma, superpower, pistis, device, mascarenes, porpoises, antigen, sentiments,
# Nearest to three: kauravas, handy, html, killer, cimeti, anamorphosis, hesitate, kerberos,
# Nearest to no: strippers, blotting, mercator, antiseptic, supercomputers, earns, ameliorated, marl,
# Nearest to however: lily, bb, announce, tia, glorioso, wangfujing, beiderbecke, klima,
# Nearest to during: crossbows, demonstrate, satan, cuisines, panarion, gruppe, woodlands, netanyahu,
# Nearest to between: snapshots, cacao, ennedi, northumbria, clearinghouse, fmf, bookmakers, nihilism,
# Nearest to i: bestowing, shutting, bertolt, maximizes, marlene, tychonoff, acquit, intravenous,
# Nearest to system: regulates, depp, limits, waugh, either, cognitively, nasrani, compared,
# Nearest to mean: aaronic, negligible, baronet, basrah, accommodation, valerian, incomprehensible, smiley,
# Nearest to paris: ulster, locker, pretend, americans, bmp, valves, organists, intonation,
# Nearest to assembly: ridged, domino, exploitation, mich, obstruents, rigel, sierra, flathead,
# Nearest to derived: castille, methods, clarification, bankhead, daydreaming, piacenza, wreck, porphyrin,
# Nearest to running: patchwork, manchu, welt, heathrow, resh, primigenius, brown, jacket,
# Nearest to ice: ua, showtime, researching, pungent, bute, mixes, jocelyn, cream,
# Nearest to shown: poodle, ignoble, adsl, radiochemistry, abandon, annals, ostensibly, costa,
# Nearest to numerous: gigahertz, audition, nus, mitrokhin, polarised, kcs, padawan, germania,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.5695 0.3431 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.5934 0.3395 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5623 0.3402 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.5724 0.3389 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.5582 0.3387 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.5876 0.3391 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.5615 0.3370 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.5483 0.3366 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.5784 0.3390 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.5698 0.3395 sec/batch
# Nearest to not: vyacheslav, aboriginal, antisymmetry, conformed, roofs, medea, puyo, vehement,
# Nearest to three: dysfunction, nucleobases, surely, dumnonii, cushitic, trajectory, gammu, deified,
# Nearest to no: anomaly, subsist, thelema, chromatography, fury, asserting, fixing, miraculously,
# Nearest to however: escalation, bathtub, temporarily, fishman, cartographer, alessandri, familjebok, fugue,
# Nearest to during: constraining, pulp, synthesis, gimlin, thanking, meaningful, vain, mitigation,
# Nearest to between: pelicans, recoil, habitation, contrast, multicultural, sloths, fondue, petitioned,
# Nearest to i: mathbb, carriages, heysel, editorials, qua, calcio, unafraid, weizenbaum,
# Nearest to system: criseyde, grosser, meister, talon, niewski, marca, holographic, paraphrased,
# Nearest to mean: grip, homicidal, maecenas, ron, intermarried, elise, turco, drumlins,
# Nearest to paris: pluto, ccr, doubted, arbeit, diwan, hayastan, graphs, plucking,
# Nearest to assembly: macrocosm, hypothesis, reece, bulges, faster, domicile, gorge, cheltenham,
# Nearest to derived: heavy, kemper, activating, oracle, mapmakers, benzoate, maaouya, regards,
# Nearest to running: sand, dug, shiloh, maguey, admissions, conspiracy, zhuhai, contradicted,
# Nearest to ice: assam, abbreviating, pentagonal, rabbah, subpages, blonde, eide, relations,
# Nearest to shown: rule, rundstedt, varphi, determined, identifies, lessens, pledging, westinghouse,
# Nearest to numerous: yerkes, butterflies, calpurnius, cookbooks, fairest, unrelated, encourage, mattia,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.5625 0.3429 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.5563 0.3380 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
